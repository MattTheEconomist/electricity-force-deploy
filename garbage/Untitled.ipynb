# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv("./data/gdpcsv.csv")
df.head()
# Out:
#          gdp  pctNation        state region   \
# 0    205,625       1.11      Alabama   South
# 1     50,404       0.27       Alaska    West
# 2    305,849       1.65      Arizona    West
# 3    121,383       0.66     Arkansas   South
# 4  2,622,731      14.17   California    West
#
#                                 industry
# 0                   health care services
# 1                 Oil and gas extraction
# 2        Ambulatory health care services
# 3        Ambulatory health care services
# 4  Computer and electronic manufacturing

# %%
df['industry'].value_counts()
# Out:
# Ambulatory health care services                          11
# Oil and gas extraction                                    6
# Hospitals, nursing, and residential care facilities       5
# Insurance carriers                                        4
# Monetary authorities                                      3
# Accommodation                                             2
# Mining (except oil and gas)                               2
# Insurance carriers                                        2
# Chemical manufacturing                                    2
# Farming                                                   2
# Broadcasting and telecommunications                       2
# Insurance carriers                                        2
# Computer and electronic product manufacturing             1
# health care services                                      1
# Broadcasting (except Internet) and telecommunications     1
# Publishing industries                                     1
# ...

# %%
# df[df['industry'].includes('Insurance')]
df[df['industry'].str.contains("Insurance")]
# Out:
#         gdp  pctNation           state    region   \
# 6   259,918       1.40     Connecticut  Northeast
# 7    71,453       0.39        Delaware      South
# 13  796,012       4.30        Illinois    Midwest
# 15  185,183       1.00            Iowa    Midwest
# 27  117,446       0.63        Nebraska    Midwest
# 29   77,208       0.42   New Hampshire  Northeast
# 35  626,622       3.39            Ohio    Midwest
# 39   57,529       0.31    Rhode Island  Northeast
# 49  313,088       1.69       Wisconsin    Midwest
#
#                                      industry
# 6                         Insurance carriers
# 7                         Insurance carriers
# 13                         Insurance carriers
# 15                         Insurance carriers
# 27                         Insurance carriers
# 29                         Insurance carriers
# 35                        Insurance carriers
# 39  Insurance carriers and related activities
# ...
